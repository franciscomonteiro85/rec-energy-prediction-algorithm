# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def get_metrics_lists(lines):
    model_names = [lines[0][:-1],lines[5][0:-1],lines[10][0:-1]]
    mse = [lines[1][-6:-1],lines[6][-6:-1],lines[11][-6:-1]]
    wape = [lines[2][-7:-1],lines[7][-7:-1],lines[12][-7:-1]]
    r2 = [lines[3][-6:-1],lines[8][-6:-1],lines[13][-6:-1]]
    mse = list(map(float, mse))
    wape = list(map(float, wape))
    wape = list(map(lambda x: x/100, wape))
    r2 = list(map(float, r2))
    return model_names, mse, wape, r2

# %%
with open('../gpu_logs/ensemble_log.txt') as f:
    lines = f.readlines()
lines = lines[-14:]
lines
# Out:
# ['XGBoost\n',
#  'Total Averaged MSE: 0.483\n',
#  'Total Averaged WAPE: 28.666\n',
#  'Total Averaged R2: 0.701\n',
#  '\n',
#  'Linear Regression\n',
#  'Total Averaged MSE: 0.21\n',
#  'Total Averaged WAPE: 29.147\n',
#  'Total Averaged R2: 0.806\n',
#  '\n',
#  'Random Forest\n',
#  'Total Averaged MSE: 0.472\n',
#  'Total Averaged WAPE: 27.514\n',
#  'Total Averaged R2: 0.718\n']

# %%
def show_graphic(lines, title, filename):
    model_names, mse, wape, r2 = get_metrics_lists(lines)
    X_names = ['MSE', 'WAPE', 'R2']
    X_axis = np.arange(len(X_names))
    plt.bar(X_axis - 0.2, (mse[0], wape[0], r2[0]), 0.2, label=model_names[0])
    plt.bar(X_axis, (mse[1], wape[1], r2[1]), 0.2, label=model_names[1])
    plt.bar(X_axis + 0.2, (mse[2], wape[2], r2[2]), 0.2, label=model_names[2])
    plt.ylim(0,1)
    plt.xticks(X_axis, X_names)
    plt.xlabel("Model Comparison")
    plt.ylabel("Metrics")
    plt.title(title)
    plt.legend()
    plt.savefig(filename)
    plt.show()

# %%
show_graphic(lines, "Comparison between 3 algorithms on energy prediction", 'images/model_comparison.png')

# %%
with open('../gpu_logs/ensemble_96.txt') as f:
    lines_96 = f.readlines()
lines_96 = lines_96[-14:]
lines_96
# Out:
# ['XGBoost\n',
#  'Total Averaged MSE: 0.346\n',
#  'Total Averaged WAPE: 28.68\n',
#  'Total Averaged R2: 0.746\n',
#  '\n',
#  'Linear Regression\n',
#  'Total Averaged MSE: 0.199\n',
#  'Total Averaged WAPE: 30.142\n',
#  'Total Averaged R2: 0.778\n',
#  '\n',
#  'Random Forest\n',
#  'Total Averaged MSE: 0.34\n',
#  'Total Averaged WAPE: 26.521\n',
#  'Total Averaged R2: 0.77\n']

# %%
show_graphic(lines_96, "Comparison between 3 algorithms on energy prediction (96 features)", 'images/model_comparison_96.png')

# %%
with open('../gpu_logs/ensemble_96_our.txt') as f:
    lines_96_our = f.readlines()
lines_96_our = lines_96_our[-14:]
lines_96_our
# Out:
# ['XGBoost\n',
#  'Total Averaged MSE: 0.075\n',
#  'Total Averaged WAPE: 39.257\n',
#  'Total Averaged R2: 0.52\n',
#  '\n',
#  'Linear Regression\n',
#  'Total Averaged MSE: 0.067\n',
#  'Total Averaged WAPE: 36.908\n',
#  'Total Averaged R2: 0.572\n',
#  '\n',
#  'Random Forest\n',
#  'Total Averaged MSE: 0.074\n',
#  'Total Averaged WAPE: 42.463\n',
#  'Total Averaged R2: 0.524\n']

# %%
show_graphic(lines_96_our, "Comparison between 3 algorithms on energy prediction (96 features - Shared Dataset)", 'images/model_comparison_96_our.png')

# %%
with open('../gpu_logs/ensemble_our_log.txt') as f:
    lines_our = f.readlines()
lines_our = lines_our[-14:]
lines_our
# Out:
# ['XGBoost\n',
#  'Total Averaged MSE: 0.054\n',
#  'Total Averaged WAPE: 40.357\n',
#  'Total Averaged R2: 0.527\n',
#  '\n',
#  'Linear Regression\n',
#  'Total Averaged MSE: 0.052\n',
#  'Total Averaged WAPE: 44.956\n',
#  'Total Averaged R2: 0.551\n',
#  '\n',
#  'Random Forest\n',
#  'Total Averaged MSE: 0.054\n',
#  'Total Averaged WAPE: 45.005\n',
#  'Total Averaged R2: 0.516\n']

# %%
show_graphic(lines_our, "Comparison between 3 algorithms on energy prediction (Shared Dataset)", 'images/model_comparison_our.png')
