# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
warnings.filterwarnings('ignore',category=DeprecationWarning)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, KFold, RepeatedKFold, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.inspection import permutation_importance
import time
import xgboost as xgb

# %%
data = pd.read_csv("output.csv")
df = data.drop(['Time'], axis=1)
number_of_houses = len(df.columns)
df
# Out:
#        PT41CV  PT44AL  PT15VP  PT69QG  PT43QL  PT87ZW
# 0       0.028   0.452   0.000   0.828   0.128   0.552
# 1       0.080   0.440   0.000   0.796   0.160   0.492
# 2       0.092   0.424   0.000   0.832   0.220   0.308
# 3       0.040   0.408   0.000   0.800   0.404   0.156
# 4       0.076   0.396   0.000   0.836   0.156   0.160
# ...       ...     ...     ...     ...     ...     ...
# 35031   0.120   0.448   0.108   0.220   0.164   0.368
# 35032   0.036   0.424   0.124   0.252   0.228   0.396
# 35033   0.064   0.392   0.148   0.268   0.224   0.356
# 35034   0.132   0.260   0.132   0.276   0.212   0.392
# 35035   0.180   0.332   0.088   0.288   0.148   0.356
#
# [35036 rows x 6 columns]

# %% [markdown]
# ## Auxiliary functions

# %%
def plot_results(preds: np.array, actuals: np.array, title: str):
    
    plt.scatter(actuals, preds, c='b', label='predicted')
    plt.xlabel('actual')
    plt.ylabel('predicted')
    plt.title(title)
    plt.xlim(0, plt.xlim()[1])
    plt.ylim(0, plt.ylim()[1])
    _ = plt.plot([0, 100], [0, 100], '--r', label='y=x')
    plt.legend()
    plt.show()
    
    
def performance_metrics(preds: np.array, actuals: np.array):

    # calculate performance metrics
    
    mse = mean_squared_error(actuals, preds)
    mae = mean_absolute_error(actuals, preds)
    rmse = np.sqrt(mse)
    wape = np.sum(np.abs(preds - actuals)) / np.sum(np.abs(actuals)) * 100
    #mape = np.mean(np.abs((actuals - preds) / actuals)) * 100
    #mape = mae / actuals.mean()  
    r2 = r2_score(actuals, preds)

    # print performance metrics
    #print('MSE: %.4f' % mse)
    #print('RMSE: %.4f' % rmse)
    #print('MAE: %.4f' % mae)
    #print('WMAPE: %.4f' % wmape)
    print('WAPE: %.4f' % wape)
    #print('R2: %.4f' % r2)
    return mse, rmse, mae, wape, r2

def build_model(estimator, X_train: np.array, y_train: np.array, X_test: np.array):
    
    model = estimator
    model.fit(X_train, y_train.values.ravel())
    preds = model.predict(X_test)
    scores = cross_validate(estimator, X_train, y_train.values.ravel(), scoring=['r2', 'neg_root_mean_squared_error', 'neg_mean_squared_error', 'neg_mean_absolute_error'])
    return model, preds, scores

# %%
def total_averaged_metrics(metrics_list):
    
    print("Total Averaged MSE: {}".format(np.round(sum(i for i, j, k, l, m in metrics_list)/len(metrics_list),3)))
    print("Total Averaged RMSE: {}".format(np.round(sum(j for i, j, k, l, m in metrics_list)/len(metrics_list),3)))
    print("Total Averaged MAE: {}".format(np.round(sum(k for i, j, k, l, m in metrics_list)/len(metrics_list),3)))
    print("Total Averaged WAPE: {}".format(np.round(sum(l for i, j, k, l, m in metrics_list)/len(metrics_list),3)))
    print("Total Averaged R2: {}".format(np.round(sum(m for i, j, k, l, m in metrics_list)/len(metrics_list),3)))


def last_energy_points(df, number_timesteps):
    X = pd.DataFrame()
    for i in range(1, (number_timesteps + 1) ):
        X[f'Energy_{i*15}'] = df.shift(i)
    X.dropna(inplace=True)
    X.reset_index(drop=True, inplace=True)
    y = pd.DataFrame(df[number_timesteps:])
    y.reset_index(drop=True, inplace=True)
    y.columns = ["Energy"]
    return X, y

def build_predict_show(df, number_timesteps, estimator, train_size=0.8, start_timestep=1 ):
    full_start = time.time()
    metrics_list = []
    for i in range(start_timestep,(number_timesteps + 1)):
        start = time.time()
        print("\nIteration ", i)
        X, y = last_energy_points(df, i)

        X_train, X_test, y_train, y_test = split_train_test_timeseries(X, y, train_size=train_size)

        model, preds, scores = build_model(estimator, X_train, y_train, X_test)
        mse, rmse, mae, mape, r2 = performance_metrics(preds, y_test.values.reshape(-1))
        cv_mse = np.round(scores['test_neg_mean_squared_error'].mean() * (-1),5)
        cv_rmse = np.round(scores['test_neg_root_mean_squared_error'].mean() * (-1),5)
        cv_mae = np.round(scores['test_neg_mean_absolute_error'].mean() * (-1),5)
        cv_r2 = np.round(scores['test_r2'].mean(),5)
        print("CV MSE: {} ".format(cv_mse))
        print("CV RMSE: {} ".format(cv_rmse))
        print("CV MAE: {} ".format(cv_mae))
        print("CV R2: {} ".format(cv_r2))
        metrics_list.append((cv_mse,cv_rmse,cv_mae,mape,cv_r2))
        print("\nElapsed time: {} seconds".format(time.time() - start))
    print("\nFull Elapsed time: {} seconds".format(time.time() - full_start))
    return model, preds, scores, metrics_list

def split_train_test_timeseries(X, y, train_size: int):
    n_train_samples = int(len(X) * train_size)
    X_train = X[:n_train_samples]
    X_test = X[n_train_samples:]
    y_train = y[:n_train_samples]
    y_test = y[n_train_samples:]
    return X_train, X_test, y_train, y_test

def show_graphic_per_timestep(metrics_list, number_timesteps, start_timestep=1):
    mse_list = []
    rmse_list = []
    mae_list = []
    wape_list = []
    r2_list = []

    for i in range(0,len(metrics_list)):
        mse_list.append(metrics_list[i][0])
        rmse_list.append(metrics_list[i][1])
        mae_list.append(metrics_list[i][2])
        wape_list.append(metrics_list[i][3])
        r2_list.append(metrics_list[i][4])
        
    plt.plot(range(start_timestep,(number_timesteps+1)), mse_list)
    plt.title('MSE per past timestep')
    plt.xlabel('Number of past timesteps')
    plt.ylabel('MSE')
    plt.show()
    
    plt.plot(range(start_timestep,(number_timesteps+1)), rmse_list)
    plt.title('RMSE per past timestep')
    plt.xlabel('Number of past timesteps')
    plt.ylabel('RMSE')
    plt.show()
    
    plt.plot(range(start_timestep,(number_timesteps+1)), mae_list)
    plt.title('MAE per past timestep')
    plt.xlabel('Number of past timesteps')
    plt.ylabel('MAE')
    plt.show()
    
    plt.plot(range(start_timestep,(number_timesteps+1)), wape_list)
    plt.title('WAPE per past timestep')
    plt.xlabel('Number of past timesteps')
    plt.ylabel('WAPE')
    plt.show()
    
    plt.plot(range(start_timestep,(number_timesteps+1)), r2_list)
    plt.title('R2 per past timestep')
    plt.xlabel('Number of past timesteps')
    plt.ylabel('R2')
    plt.show()

# %%
df_total = pd.DataFrame(df.sum(axis=1))
df_total.columns = ['Energy']
df_total
# Out:
#        Energy
# 0       1.988
# 1       1.968
# 2       1.876
# 3       1.808
# 4       1.624
# ...       ...
# 35031   1.428
# 35032   1.460
# 35033   1.452
# 35034   1.404
# 35035   1.392
#
# [35036 rows x 1 columns]

# %% [markdown]
# ### Normalize data

# %%
values = df_total.values
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(values)
df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = ['Energy']
df_scaled
# Out:
#          Energy
# 0      0.151722
# 1      0.149830
# 2      0.141128
# 3      0.134695
# 4      0.117291
# ...         ...
# 35031  0.098751
# 35032  0.101778
# 35033  0.101022
# 35034  0.096481
# 35035  0.095346
#
# [35036 rows x 1 columns]

# %% [markdown]
# ## Preprocessing

# %%
X,y = last_energy_points(df_total, 8)
print(X.shape, y.shape)
X
# Out:
# (35028, 8) (35028, 1)
#        Energy_15  Energy_30  Energy_45  Energy_60  Energy_75  Energy_90  \
# 0          1.532      1.748      1.688      1.624      1.808      1.876
# 1          1.548      1.532      1.748      1.688      1.624      1.808
# 2          1.028      1.548      1.532      1.748      1.688      1.624
# 3          0.844      1.028      1.548      1.532      1.748      1.688
# 4          0.812      0.844      1.028      1.548      1.532      1.748
# ...          ...        ...        ...        ...        ...        ...
# 35023      1.372      1.464      1.656      1.668      1.844      2.084
# 35024      1.428      1.372      1.464      1.656      1.668      1.844
# 35025      1.460      1.428      1.372      1.464      1.656      1.668
# 35026      1.452      1.460      1.428      1.372      1.464      1.656
# 35027      1.404      1.452      1.460      1.428      1.372      1.464
#
#        Energy_105  Energy_120
# 0           1.968       1.988
# 1           1.876       1.968
# 2           1.808       1.876
# 3           1.624       1.808
# 4           1.688       1.624
# ...           ...         ...
# 35023       2.012       2.136
# 35024       2.084       2.012
# 35025       1.844       2.084
# 35026       1.668       1.844
# 35027       1.656       1.668
#
# [35028 rows x 8 columns]

# %% [markdown]
# ## Test model

# %% [markdown]
# ### Gradient Boosting

# %%
start_timestep = 2
number_timesteps = 12

# %%
model_gb, preds_gb, scores_gb, metrics_list_gb = build_predict_show(df_total, number_timesteps, GradientBoostingRegressor(random_state=42), start_timestep=start_timestep)
# Out:
# Iteration  2
# WAPE: 19.7164
# CV MSE: 0.33
# CV RMSE: 0.572
# CV MAE: 0.359
# CV R2: 0.618
#
# Elapsed time: 5.0 seconds
#
# Iteration  3
# WAPE: 19.5455
# CV MSE: 0.323
# CV RMSE: 0.566
# CV MAE: 0.356
# CV R2: 0.627
#
# Elapsed time: 7.0 seconds
#
# Iteration  4
# WAPE: 19.5715
# CV MSE: 0.322
# CV RMSE: 0.565
# CV MAE: 0.357
# CV R2: 0.626
#
# Elapsed time: 10.0 seconds
#
# Iteration  5
# WAPE: 19.5940
# CV MSE: 0.322
# CV RMSE: 0.565
# CV MAE: 0.356
# CV R2: 0.627
#
# Elapsed time: 12.0 seconds
#
# Iteration  6
# WAPE: 19.5732
# CV MSE: 0.322
# CV RMSE: 0.565
# CV MAE: 0.357
# CV R2: 0.627
#
# Elapsed time: 14.0 seconds
#
# Iteration  7
# WAPE: 19.5435
# CV MSE: 0.322
# CV RMSE: 0.565
# CV MAE: 0.357
# CV R2: 0.627
#
# Elapsed time: 16.0 seconds
#
# Iteration  8
# WAPE: 19.5409
# CV MSE: 0.323
# CV RMSE: 0.566
# CV MAE: 0.357
# CV R2: 0.625
#
# Elapsed time: 18.0 seconds
#
# Iteration  9
# WAPE: 19.5427
# CV MSE: 0.324
# CV RMSE: 0.567
# CV MAE: 0.358
# CV R2: 0.624
#
# Elapsed time: 20.0 seconds
#
# Iteration  10
# WAPE: 19.5315
# CV MSE: 0.324
# CV RMSE: 0.567
# CV MAE: 0.357
# CV R2: 0.624
#
# Elapsed time: 23.0 seconds
#
# Iteration  11
# WAPE: 19.5525
# CV MSE: 0.324
# CV RMSE: 0.567
# CV MAE: 0.358
# CV R2: 0.624
#
# Elapsed time: 25.0 seconds
#
# Iteration  12
# WAPE: 19.5358
# CV MSE: 0.324
# CV RMSE: 0.567
# CV MAE: 0.358
# CV R2: 0.624
#
# Elapsed time: 27.0 seconds
#
# Full Elapsed time: 178.0 seconds

# %%
show_graphic_per_timestep(metrics_list_gb, number_timesteps, start_timestep)

# %% [markdown]
# #### Normalized

# %%
model_gb_norm, preds_gb_norm, scores_gb_norm, metrics_list_gb_norm = build_predict_show(df_scaled, number_timesteps, GradientBoostingRegressor(random_state=42), start_timestep=start_timestep)
# Out:
# Iteration  2
# WAPE: 24.8258
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.617
#
# Elapsed time: 5.0 seconds
#
# Iteration  3
# WAPE: 24.6112
# CV MSE: 0.003
# CV RMSE: 0.053
# CV MAE: 0.034
# CV R2: 0.627
#
# Elapsed time: 7.0 seconds
#
# Iteration  4
# WAPE: 24.6421
# CV MSE: 0.003
# CV RMSE: 0.053
# CV MAE: 0.034
# CV R2: 0.626
#
# Elapsed time: 9.0 seconds
#
# Iteration  5
# WAPE: 24.6719
# CV MSE: 0.003
# CV RMSE: 0.053
# CV MAE: 0.034
# CV R2: 0.628
#
# Elapsed time: 13.0 seconds
#
# Iteration  6
# WAPE: 24.6470
# CV MSE: 0.003
# CV RMSE: 0.053
# CV MAE: 0.034
# CV R2: 0.627
#
# Elapsed time: 15.0 seconds
#
# Iteration  7
# WAPE: 24.6088
# CV MSE: 0.003
# CV RMSE: 0.053
# CV MAE: 0.034
# CV R2: 0.627
#
# Elapsed time: 17.0 seconds
#
# Iteration  8
# WAPE: 24.6027
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.625
#
# Elapsed time: 20.0 seconds
#
# Iteration  9
# WAPE: 24.6070
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.624
#
# Elapsed time: 22.0 seconds
#
# Iteration  10
# WAPE: 24.5903
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.625
#
# Elapsed time: 25.0 seconds
#
# Iteration  11
# WAPE: 24.6199
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.624
#
# Elapsed time: 27.0 seconds
#
# Iteration  12
# WAPE: 24.5989
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.624
#
# Elapsed time: 30.0 seconds
#
# Full Elapsed time: 192.0 seconds

# %%
show_graphic_per_timestep(metrics_list_gb_norm, number_timesteps, start_timestep)

# %% [markdown]
# ### Random Forest

# %%
model_rf, preds_rf, scores_rf, metrics_list_rf = build_predict_show(df_total, number_timesteps, RandomForestRegressor(random_state=42), start_timestep=start_timestep)
# Out:
# Iteration  2
# WAPE: 23.0268
# CV MSE: 0.401
# CV RMSE: 0.631
# CV MAE: 0.41
# CV R2: 0.535
#
# Elapsed time: 25.0 seconds
#
# Iteration  3
# WAPE: 21.4962
# CV MSE: 0.363
# CV RMSE: 0.6
# CV MAE: 0.389
# CV R2: 0.578
#
# Elapsed time: 38.0 seconds
#
# Iteration  4
# WAPE: 21.2010
# CV MSE: 0.351
# CV RMSE: 0.59
# CV MAE: 0.381
# CV R2: 0.592
#
# Elapsed time: 47.0 seconds
#
# Iteration  5
# WAPE: 20.8874
# CV MSE: 0.346
# CV RMSE: 0.586
# CV MAE: 0.378
# CV R2: 0.599
#
# Elapsed time: 59.0 seconds
#
# Iteration  6
# WAPE: 20.6859
# CV MSE: 0.342
# CV RMSE: 0.583
# CV MAE: 0.375
# CV R2: 0.603
#
# Elapsed time: 83.0 seconds
#
# Iteration  7
# WAPE: 20.6289
# CV MSE: 0.342
# CV RMSE: 0.583
# CV MAE: 0.375
# CV R2: 0.603
#
# Elapsed time: 98.0 seconds
#
# Iteration  8
# WAPE: 20.5591
# CV MSE: 0.338
# CV RMSE: 0.58
# CV MAE: 0.373
# CV R2: 0.606
#
# Elapsed time: 111.0 seconds
#
# Iteration  9
# WAPE: 20.4742
# CV MSE: 0.34
# CV RMSE: 0.581
# CV MAE: 0.374
# CV R2: 0.605
#
# Elapsed time: 119.0 seconds
#
# Iteration  10
# WAPE: 20.3652
# CV MSE: 0.339
# CV RMSE: 0.58
# CV MAE: 0.373
# CV R2: 0.606
#
# Elapsed time: 132.0 seconds
#
# Iteration  11
# WAPE: 20.4503
# CV MSE: 0.34
# CV RMSE: 0.581
# CV MAE: 0.374
# CV R2: 0.604
#
# Elapsed time: 152.0 seconds
#
# Iteration  12
# WAPE: 20.4389
# CV MSE: 0.338
# CV RMSE: 0.58
# CV MAE: 0.373
# CV R2: 0.606
#
# Elapsed time: 158.0 seconds
#
# Full Elapsed time: 1022.0 seconds

# %%
show_graphic_per_timestep(metrics_list_rf, number_timesteps, start_timestep=start_timestep)

# %% [markdown]
# #### Normalized

# %%
model_rf_norm, preds_rf_norm, scores_rf_norm, metrics_list_rf_norm = build_predict_show(df_scaled, number_timesteps, RandomForestRegressor(random_state=42), start_timestep=start_timestep)
# Out:
# Iteration  2
# WAPE: 29.0573
# CV MSE: 0.004
# CV RMSE: 0.06
# CV MAE: 0.039
# CV R2: 0.536
#
# Elapsed time: 24.0 seconds
#
# Iteration  3
# WAPE: 27.0994
# CV MSE: 0.003
# CV RMSE: 0.057
# CV MAE: 0.037
# CV R2: 0.579
#
# Elapsed time: 37.0 seconds
#
# Iteration  4
# WAPE: 26.7063
# CV MSE: 0.003
# CV RMSE: 0.056
# CV MAE: 0.036
# CV R2: 0.592
#
# Elapsed time: 47.0 seconds
#
# Iteration  5
# WAPE: 26.2879
# CV MSE: 0.003
# CV RMSE: 0.055
# CV MAE: 0.036
# CV R2: 0.599
#
# Elapsed time: 60.0 seconds
#
# Iteration  6
# WAPE: 26.0653
# CV MSE: 0.003
# CV RMSE: 0.055
# CV MAE: 0.036
# CV R2: 0.603
#
# Elapsed time: 69.0 seconds
#
# Iteration  7
# WAPE: 25.9905
# CV MSE: 0.003
# CV RMSE: 0.055
# CV MAE: 0.035
# CV R2: 0.603
#
# Elapsed time: 82.0 seconds
#
# Iteration  8
# WAPE: 25.9093
# CV MSE: 0.003
# CV RMSE: 0.055
# CV MAE: 0.035
# CV R2: 0.606
#
# Elapsed time: 97.0 seconds
#
# Iteration  9
# WAPE: 25.7619
# CV MSE: 0.003
# CV RMSE: 0.055
# CV MAE: 0.035
# CV R2: 0.605
#
# Elapsed time: 123.0 seconds
#
# Iteration  10
# WAPE: 25.6342
# CV MSE: 0.003
# CV RMSE: 0.055
# CV MAE: 0.035
# CV R2: 0.606
#
# Elapsed time: 137.0 seconds
#
# Iteration  11
# WAPE: 25.7420
# CV MSE: 0.003
# CV RMSE: 0.055
# CV MAE: 0.035
# CV R2: 0.604
#
# Elapsed time: 153.0 seconds
#
# Iteration  12
# WAPE: 25.7051
# CV MSE: 0.003
# CV RMSE: 0.055
# CV MAE: 0.035
# CV R2: 0.606
#
# Elapsed time: 154.0 seconds
#
# Full Elapsed time: 983.0 seconds

# %%
show_graphic_per_timestep(metrics_list_rf_norm, number_timesteps, start_timestep=start_timestep)

# %% [markdown]
# ## XGBoost

# %%
model_xgb, preds_xgb, scores_xgb, metrics_list_xgb = build_predict_show(df_total, number_timesteps, xgb.XGBRegressor(max_depth=5, learning_rate=0.1, n_estimators=100, seed=42), start_timestep=start_timestep)
# Out:
# Iteration  2
# WAPE: 19.8690
# CV MSE: 0.335
# CV RMSE: 0.576
# CV MAE: 0.361
# CV R2: 0.612
#
# Elapsed time: 3.0 seconds
#
# Iteration  3
# WAPE: 19.7362
# CV MSE: 0.325
# CV RMSE: 0.567
# CV MAE: 0.357
# CV R2: 0.624
#
# Elapsed time: 3.0 seconds
#
# Iteration  4
# WAPE: 19.7581
# CV MSE: 0.325
# CV RMSE: 0.568
# CV MAE: 0.358
# CV R2: 0.624
#
# Elapsed time: 3.0 seconds
#
# Iteration  5
# WAPE: 19.7358
# CV MSE: 0.325
# CV RMSE: 0.568
# CV MAE: 0.358
# CV R2: 0.623
#
# Elapsed time: 3.0 seconds
#
# Iteration  6
# WAPE: 19.7008
# CV MSE: 0.325
# CV RMSE: 0.568
# CV MAE: 0.358
# CV R2: 0.624
#
# Elapsed time: 3.0 seconds
#
# Iteration  7
# WAPE: 19.6682
# CV MSE: 0.325
# CV RMSE: 0.568
# CV MAE: 0.358
# CV R2: 0.623
#
# Elapsed time: 3.0 seconds
#
# Iteration  8
# WAPE: 19.6518
# CV MSE: 0.325
# CV RMSE: 0.568
# CV MAE: 0.358
# CV R2: 0.623
#
# Elapsed time: 4.0 seconds
#
# Iteration  9
# WAPE: 19.6471
# CV MSE: 0.326
# CV RMSE: 0.568
# CV MAE: 0.358
# CV R2: 0.622
#
# Elapsed time: 5.0 seconds
#
# Iteration  10
# WAPE: 19.6329
# CV MSE: 0.326
# CV RMSE: 0.569
# CV MAE: 0.358
# CV R2: 0.622
#
# Elapsed time: 5.0 seconds
#
# Iteration  11
# WAPE: 19.6512
# CV MSE: 0.326
# CV RMSE: 0.569
# CV MAE: 0.359
# CV R2: 0.622
#
# Elapsed time: 10.0 seconds
#
# Iteration  12
# WAPE: 19.6641
# CV MSE: 0.326
# CV RMSE: 0.569
# CV MAE: 0.359
# CV R2: 0.621
#
# Elapsed time: 6.0 seconds
#
# Full Elapsed time: 48.0 seconds

# %%
show_graphic_per_timestep(metrics_list_xgb, number_timesteps, start_timestep=start_timestep)

# %% [markdown]
# #### Normalized

# %%
model_xgb_norm, preds_xgb_norm, scores_xgb_norm, metrics_list_xgb_norm = build_predict_show(df_scaled, number_timesteps, xgb.XGBRegressor(max_depth=5, learning_rate=0.1, n_estimators=100, seed=42), start_timestep=start_timestep)
# Out:
# Iteration  2
# WAPE: 24.9804
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.613
#
# Elapsed time: 3.0 seconds
#
# Iteration  3
# WAPE: 24.8089
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.623
#
# Elapsed time: 3.0 seconds
#
# Iteration  4
# WAPE: 24.8830
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.623
#
# Elapsed time: 3.0 seconds
#
# Iteration  5
# WAPE: 24.8512
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.623
#
# Elapsed time: 3.0 seconds
#
# Iteration  6
# WAPE: 24.8219
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.624
#
# Elapsed time: 3.0 seconds
#
# Iteration  7
# WAPE: 24.7566
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.623
#
# Elapsed time: 3.0 seconds
#
# Iteration  8
# WAPE: 24.7328
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.622
#
# Elapsed time: 4.0 seconds
#
# Iteration  9
# WAPE: 24.7385
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.621
#
# Elapsed time: 5.0 seconds
#
# Iteration  10
# WAPE: 24.7603
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.622
#
# Elapsed time: 5.0 seconds
#
# Iteration  11
# WAPE: 24.7194
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.62
#
# Elapsed time: 5.0 seconds
#
# Iteration  12
# WAPE: 24.7429
# CV MSE: 0.003
# CV RMSE: 0.054
# CV MAE: 0.034
# CV R2: 0.621
#
# Elapsed time: 5.0 seconds
#
# Full Elapsed time: 43.0 seconds

# %%
show_graphic_per_timestep(metrics_list_xgb_norm, number_timesteps, start_timestep=start_timestep)

# %%
print(min([sublist[3] for sublist in metrics_list_gb]))
print(min([sublist[3] for sublist in metrics_list_gb_norm]))
print(min([sublist[3] for sublist in metrics_list_rf]))
print(min([sublist[3] for sublist in metrics_list_rf_norm]))
print(min([sublist[3] for sublist in metrics_list_xgb]))
print(min([sublist[3] for sublist in metrics_list_xgb_norm]))
# Out:
# 19.531488022941243
# 24.5902647485894
# 20.365196383682196
# 25.634200499424175
# 19.632933358841324
# 24.719377110103295

# %%
def switch_metric(metric: str):
    if metric.lower() == "mse":
        m = 0
    elif metric.lower() == "rmse":
        m = 1
    elif metric.lower() == "mae":
        m = 2
    elif metric.lower() == "wape":
        m = 3
    elif metric.lower() == "r2":
        m = 4
    return m

# %%
def find_best_model(metric: str, metrics_list):
    met = switch_metric(metric)
    min_value = min(map(lambda x: x[met], metrics_list))
    idx = [index for index, item in enumerate(map(lambda x: x[met], metrics_list)) if item == min_value]
    return metrics_list[idx[0]]

# %%
all_metrics_lists = [metrics_list_gb, metrics_list_gb_norm, metrics_list_rf, metrics_list_rf_norm, metrics_list_xgb, metrics_list_xgb_norm]

# %%
best_model = []
for model in all_metrics_lists:
    best_model.append(find_best_model("wape", model))

# %% [markdown]
# ### Plot Best models

# %%
X_names = ("WAPE", "R2")
X_axis = np.arange(len(X_names))
plt.bar(X_axis - 0.2, (best_model[0][3] / 100, best_model[0][4]), 0.2, label = 'Denormalized GB')
plt.bar(X_axis, (best_model[2][3] / 100, best_model[2][4]), 0.2, label = 'Denormalized RF')
plt.bar(X_axis + 0.2, (best_model[4][3] / 100, best_model[4][4]), 0.2, label = 'Denormalized XGB')
plt.ylim(0,1)
plt.xticks(X_axis, X_names)
plt.xlabel("Individual vs Sum")
plt.ylabel("Metrics")
plt.title("Denormalized")
plt.legend()
plt.show()

# %%
X_names = ("WAPE", "R2")
X_axis = np.arange(len(X_names))
plt.bar(X_axis - 0.2, (best_model[1][3] / 100, best_model[1][4]), 0.2, label = 'Normalized GB')
plt.bar(X_axis + 0, (best_model[3][3] / 100, best_model[3][4]), 0.2, label = 'Normalized RF')
plt.bar(X_axis + 0.2, (best_model[5][3] / 100, best_model[5][4]), 0.2, label = 'Normalized XGB')

plt.ylim(0,1)
plt.xticks(X_axis, X_names)
plt.xlabel("Individual vs Sum")
plt.ylabel("Metrics")
plt.title("Individual average vs Energy sum (previous week)")
plt.legend()
plt.show()

# %%
X_names = ("WAPE", "R2")
X_axis = np.arange(len(X_names))
plt.bar(X_axis - 0.2, (best_model[0][3] / 100, best_model[0][4]), 0.4, label = 'Denormalized GB')
plt.bar(X_axis + 0.2, (best_model[1][3] / 100, best_model[1][4]), 0.4, label = 'Normalized GB')
plt.ylim(0,1)
plt.xticks(X_axis, X_names)
plt.xlabel("Metrics")
plt.ylabel("Values")
plt.title("Normalized vs Denormalied GB")
plt.legend()
plt.show()

# %%
X_names = ("WAPE", "R2")
X_axis = np.arange(len(X_names))
plt.bar(X_axis - 0.2, (best_model[2][3] / 100, best_model[2][4]), 0.4, label = 'Denormalized RF')
plt.bar(X_axis + 0.2, (best_model[3][3] / 100, best_model[3][4]), 0.4, label = 'Normalized RF')
plt.ylim(0,1)
plt.xticks(X_axis, X_names)
plt.xlabel("Metrics")
plt.ylabel("Values")
plt.title("Normalized vs Denormalied RF")
plt.legend()
plt.show()

# %%
X_names = ("WAPE", "R2")
X_axis = np.arange(len(X_names))
plt.bar(X_axis - 0.2, (best_model[4][3] / 100, best_model[4][4]), 0.4, label = 'Denormalized XGB')
plt.bar(X_axis + 0.2, (best_model[5][3] / 100, best_model[5][4]), 0.4, label = 'Normalized XGB')
plt.ylim(0,1)
plt.xticks(X_axis, X_names)
plt.xlabel("Metrics")
plt.ylabel("Values")
plt.title("Normalized vs Denormalized XGB")
plt.legend()
plt.show()

# %% [markdown]
# ## Best model

# %%
test_score = np.zeros((params['n_estimators'],), dtype=np.float64)
for i, y_pred in enumerate(model.staged_predict(X_test)):
    test_score[i] = mean_squared_error(y_test, y_pred)

fig = plt.figure(figsize=(6, 6))
plt.subplot(1, 1, 1)
plt.title("Deviance")
plt.plot(
    np.arange(params['n_estimators']) + 1,
    model.train_score_,
    "b-",
    label="Training Set Deviance",
)
plt.plot(
    np.arange(params['n_estimators']) + 1, test_score, "r-", label="Test Set Deviance"
)
plt.legend(loc="upper right")
plt.xlabel("Boosting Iterations")
plt.ylabel("Deviance")
fig.tight_layout()
plt.show()

# %%
feature_importance = model.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + 0.5
fig = plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.barh(pos, feature_importance[sorted_idx], align="center")
plt.yticks(pos,X_test.columns)
plt.title("Feature Importance (MDI)")

result = permutation_importance(
    model, X_test, y_test, n_repeats=10, random_state=42, n_jobs=2
)
sorted_idx = result.importances_mean.argsort()
plt.subplot(1, 2, 2)
plt.boxplot(
    result.importances[sorted_idx].T,
    vert=False,
    labels=X_test.columns,
)
plt.title("Permutation Importance (test set)")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Hyperparameter tuning

# %%
grid = dict()
grid['n_estimators'] = [50, 100, 500]
grid['learning_rate'] = [0.001, 0.01, 0.1, 0.3]
grid['subsample'] = [0.5, 0.7, 1.0]
grid['max_depth'] = [3, 7, 9]

model = GradientBoostingRegressor()
cv = RepeatedKFold(n_splits=10, random_state=1)
#grid_search = RandomizedSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv)
grid_result = grid_search.fit(X, y.values.ravel())

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
