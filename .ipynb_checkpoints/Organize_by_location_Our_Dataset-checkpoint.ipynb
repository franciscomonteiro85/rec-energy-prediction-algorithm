# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
warnings.filterwarnings('ignore',category=DeprecationWarning)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, KFold, RepeatedKFold, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.inspection import permutation_importance
import time
import xgboost as xgb

# %%
data = pd.read_csv("output.csv")
df = data.drop(['Time'], axis=1)
number_of_houses = len(df.columns)
df
# Out:
#        PT41CV  PT44AL  PT15VP  PT69QG  PT43QL  PT17RW  PT87ZW
# 0       0.028   0.452   0.000   0.828   0.128   0.056   0.552
# 1       0.080   0.440   0.000   0.796   0.160   0.056   0.492
# 2       0.092   0.424   0.000   0.832   0.220   0.056   0.308
# 3       0.040   0.408   0.000   0.800   0.404   0.088   0.156
# 4       0.076   0.396   0.000   0.836   0.156   0.116   0.160
# ...       ...     ...     ...     ...     ...     ...     ...
# 35027   0.120   0.448   0.108   0.220   0.164   0.144   0.368
# 35028   0.036   0.424   0.124   0.252   0.228   0.164   0.396
# 35029   0.064   0.392   0.148   0.268   0.224   0.220   0.356
# 35030   0.132   0.260   0.132   0.276   0.212   0.176   0.392
# 35031   0.180   0.332   0.088   0.288   0.148   0.132   0.356
#
# [35032 rows x 7 columns]

# %%
data['Time']
# Out:
# 0        2021-11-01 00:15:00
# 1        2021-11-01 00:30:00
# 2        2021-11-01 00:45:00
# 3        2021-11-01 01:00:00
# 4        2021-11-01 01:15:00
#                 ...
# 35027    2022-10-31 23:00:00
# 35028    2022-10-31 23:15:00
# 35029    2022-10-31 23:30:00
# 35030    2022-10-31 23:45:00
# 35031    2022-11-01 00:00:00
# Name: Time, Length: 35032, dtype: object

# %%
house_list = []
test = data['Time']
for i in df:
    test = pd.concat([test, df[i]], axis=1)
    test = test.rename(columns={i: 'Energy'})
    test['Location'] = i
    house_list.append(test)

# %%
house_list
# Out:
# [                      Time  Energy Location
#  0      2021-11-01 00:15:00   0.028   PT41CV
#  1      2021-11-01 00:30:00   0.080   PT41CV
#  2      2021-11-01 00:45:00   0.092   PT41CV
#  3      2021-11-01 01:00:00   0.040   PT41CV
#  4      2021-11-01 01:15:00   0.076   PT41CV
#  ...                    ...     ...      ...
#  35027  2022-10-31 23:00:00   0.120   PT41CV
#  35028  2022-10-31 23:15:00   0.036   PT41CV
#  35029  2022-10-31 23:30:00   0.064   PT41CV
#  35030  2022-10-31 23:45:00   0.132   PT41CV
#  35031  2022-11-01 00:00:00   0.180   PT41CV
#
#  [35032 rows x 3 columns],
#                        Time  Energy Location  Energy
#  0      2021-11-01 00:15:00   0.028   PT44AL   0.452
#  1      2021-11-01 00:30:00   0.080   PT44AL   0.440
#  2      2021-11-01 00:45:00   0.092   PT44AL   0.424
#  3      2021-11-01 01:00:00   0.040   PT44AL   0.408
#  4      2021-11-01 01:15:00   0.076   PT44AL   0.396
#  ...                    ...     ...      ...     ...
#  35027  2022-10-31 23:00:00   0.120   PT44AL   0.448
#  35028  2022-10-31 23:15:00   0.036   PT44AL   0.424
#  35029  2022-10-31 23:30:00   0.064   PT44AL   0.392
#  35030  2022-10-31 23:45:00   0.132   PT44AL   0.260
#  35031  2022-11-01 00:00:00   0.180   PT44AL   0.332
#
#  [35032 rows x 4 columns],
#                        Time  Energy Location  Energy  Energy
#  ...                    ...     ...      ...     ...     ...     ...     ...
#  35027  2022-10-31 23:00:00   0.120   PT17RW   0.448   0.108   0.220   0.164
#  35028  2022-10-31 23:15:00   0.036   PT17RW   0.424   0.124   0.252   0.228
#  35029  2022-10-31 23:30:00   0.064   PT17RW   0.392   0.148   0.268   0.224
#  35030  2022-10-31 23:45:00   0.132   PT17RW   0.260   0.132   0.276   0.212
#  35031  2022-11-01 00:00:00   0.180   PT17RW   0.332   0.088   0.288   0.148
#
#         Energy
#  0       0.056
#  1       0.056
#  2       0.056
#  3       0.088
#  4       0.116
#  ...       ...
#  35027   0.144
#  35028   0.164
#  35029   0.220
#  35030   0.176
#  35031   0.132
#
#  [35032 rows x 8 columns],
#                        Time  Energy Location  Energy  Energy  Energy  Energy  \
#  0      2021-11-01 00:15:00   0.028   PT87ZW   0.452   0.000   0.828   0.128
#  1      2021-11-01 00:30:00   0.080   PT87ZW   0.440   0.000   0.796   0.160
#  2      2021-11-01 00:45:00   0.092   PT87ZW   0.424   0.000   0.832   0.220
#  3      2021-11-01 01:00:00   0.040   PT87ZW   0.408   0.000   0.800   0.404
#  4      2021-11-01 01:15:00   0.076   PT87ZW   0.396   0.000   0.836   0.156
#  ...                    ...     ...      ...     ...     ...     ...     ...
#  35027  2022-10-31 23:00:00   0.120   PT87ZW   0.448   0.108   0.220   0.164
#  35028  2022-10-31 23:15:00   0.036   PT87ZW   0.424   0.124   0.252   0.228
#  35029  2022-10-31 23:30:00   0.064   PT87ZW   0.392   0.148   0.268   0.224
#  35030  2022-10-31 23:45:00   0.132   PT87ZW   0.260   0.132   0.276   0.212
#  35031  2022-11-01 00:00:00   0.180   PT87ZW   0.332   0.088   0.288   0.148
#
#         Energy  Energy
#  0       0.056   0.552
#  1       0.056   0.492
#  2       0.056   0.308
#  3       0.088   0.156
#  4       0.116   0.160
#  ...       ...     ...
#  35027   0.144   0.368
#  35028   0.164   0.396
#  35029   0.220   0.356
#  35030   0.176   0.392
#  35031   0.132   0.356
#
#  [35032 rows x 9 columns]]

# %%
df_location = house_list[0]
for i in house_list[1:]:
    df_location = pd.concat([df_location, i], axis=0)
df_location.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 df_location = house_list[0]
#       2 for i in house_list[1:]:
# ----> 3     df_location = pd.concat([df_location, i], axis=0)
#       4 df_location.reset_index(drop=True)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py:381, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     159 """
#     160 Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366 1   3   4
#     367 """
#     368 op = _Concatenator(
#     369     objs,
#     370     axis=axis,
#    (...)
#     378     sort=sort,
#     379 )
# --> 381 return op.get_result()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py:612, in _Concatenator.get_result(self)
#     610         obj_labels = obj.axes[1 - ax]
#     611         if not new_labels.equals(obj_labels):
# --> 612             indexers[ax] = obj_labels.get_indexer(new_labels)
#     614     mgrs_indexers.append((obj._mgr, indexers))
#     616 new_data = concatenate_managers(
#     617     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     618 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3905, in Index.get_indexer(self, target, method, limit, tolerance)
#    3902 self._check_indexing_method(method, limit, tolerance)
#    3904 if not self._index_as_unique:
# -> 3905     raise InvalidIndexError(self._requires_unique_msg)
#    3907 if len(target) == 0:
#    3908     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
df_location.to_pickle("df_location.pkl")
